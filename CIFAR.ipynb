# %%
import numpy as np
import matplotlib.pyplot as plt

import torch
from torch import optim
from torchvision.transforms import RandomHorizontalFlip

from models import U_Net_big
from RectifiedFlow import RectifiedFlow_Unet, train

from util import load_Cifar10, show_samples, show_trajectories

# %%
if torch.cuda.is_available():
    device = "cuda"
else:
    device = "cpu"
print(device)
# Out:
# cuda

# %%
batch_size = 512
train_dataset, test_dataset, train_dataloader, test_dataloader, classes = load_Cifar10(batch_size)
input_shape = (batch_size, 4, 32, 32)

def get_samples(shape, device):
    return torch.randn(shape, device=device)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
data = torch.tensor(train_dataset.data).permute([0,3,1,2])
print(data.shape)
plt.figure(figsize=(2,2))
plt.imshow(data[0].permute([1,2,0]))
plt.show()
hflipper = RandomHorizontalFlip(p=0.5)
transformed_imgs = hflipper(data)
plt.imshow(transformed_imgs[89].permute([1,2,0]))
plt.show()
# Out:
# torch.Size([50000, 3, 32, 32])

# %%
v_model_1 = U_Net_big(input_shape=input_shape, output_channels=3, device=device)
rectified_flow_1 = RectifiedFlow_Unet(v_model_1, device)

# %%
optimizer_1 = torch.optim.Adam(rectified_flow_1.v_model.parameters(), lr=2e-4, weight_decay=10e-5)
scheduler_1 = None #optim.lr_scheduler.ReduceLROnPlateau(optimizer_1, factor=0.9, patience=120, verbose=True)

# %%
optimizer_1.__setattr__("lr", 5e-5)

# %%
rectified_flow_1 = train(rectified_flow_1, False, optimizer_1, scheduler_1, train_dataloader, get_samples, device, epochs=100, noise_factor=0.008, flip=True)
plt.plot(np.log(rectified_flow_1.loss_curve))
plt.show()

# %%
torch.save(rectified_flow_1, "./models/CIFAR10/cifar10.pth")

# %%
rectified_flow_1 = torch.load("./models/CIFAR10/cifar10.pth")

# %%
def get_samples(shape, device):
    return torch.randn(shape, device=device)

# %%
rectified_flow_1.v_model.eval()
img_init = torch.randn(1,3,32,32).to(device) * 0.9
img = rectified_flow_1.sample_ode(img_init, 100)

# print(img[-1])

min = torch.min(img[-1][0])
img[-1][0] = img[-1][0] - min
max = torch.max(img[-1][0])
img[-1][0] = img[-1][0] / max

plt.figure(figsize=(2,2))
plt.imshow(img[-1][0].permute(1,2,0).detach().cpu().numpy())
plt.show()

# %%
show_samples(rectified_flow_1, get_samples, columns=5, rows=2, channels=3, img_size=32, num_steps=100, device=device)

# %%
show_trajectories(rectified_flow_1, get_samples, img_size=32, num_steps=100, device=device)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /home/max/Documents/RectifiedFlow/RectifiedFlow/CIFAR_car.ipynb Cell 17 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/home/max/Documents/RectifiedFlow/RectifiedFlow/CIFAR_car.ipynb#X16sZmlsZQ%3D%3D?line=0'>1</a> show_trajectories(rectified_flow_1, get_samples, img_size=32, num_steps=100, device=device)
#
# File ~/Documents/RectifiedFlow/RectifiedFlow/util.py:42, in show_trajectories(rectified_flow, get_samples, img_size, num_steps, device)
#      40 rectified_flow.v_model.eval()
#      41 img_init = get_samples((20, 1, img_size, img_size), device=device)
# ---> 42 img = rectified_flow.sample_ode(img_init, 100)
#      43 s = torch.zeros(20, len(img), 1, 32, 32)
#      44 for i in range(len(img)):
#
# File ~/anaconda3/envs/ML/lib/python3.9/site-packages/torch/autograd/grad_mode.py:27, in _DecoratorContextManager.__call__.<locals>.decorate_context(*args, **kwargs)
#      24 @functools.wraps(func)
#      25 def decorate_context(*args, **kwargs):
#      26     with self.clone():
# ---> 27         return func(*args, **kwargs)
#
# File ~/Documents/RectifiedFlow/RectifiedFlow/RectifiedFlow.py:270, in RectifiedFlow_Unet.sample_ode(self, z0, num_steps)
#     267 for i in range(num_steps):
#     268     t = torch.ones(batchsize).to(self.device) * i / num_steps
# --> 270     pred = self.v_model(t, z)
#     271     z = z.detach().clone() + pred * dt
#     273     trajectory.append(z.detach().clone())
#
# File ~/anaconda3/envs/ML/lib/python3.9/site-packages/torch/nn/modules/module.py:1130, in Module._call_impl(self, *input, **kwargs)
#    1126 # If we don't have any hooks, we want to skip the rest of the logic in
#    1127 # this function, and just call forward.
#    1128 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130     return forward_call(*input, **kwargs)
#    1131 # Do not call functions when jit is used
#    1132 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/Documents/RectifiedFlow/RectifiedFlow/models.py:206, in U_Net_big.forward(self, t, x, c)
#     203 else:
#     204     x_input = torch.cat([x, t_expand], axis=1).reshape(-1, x.shape[1] + 1,32,32)
# --> 206 skip_1 = self.NN['contr_1'](x_input)
#     207 contr_1 = self.NN["max_pool"](skip_1)
#     208 skip_2 = self.NN["contr_2"](contr_1)
#
# File ~/anaconda3/envs/ML/lib/python3.9/site-packages/torch/nn/modules/module.py:1130, in Module._call_impl(self, *input, **kwargs)
#    1126 # If we don't have any hooks, we want to skip the rest of the logic in
#    1127 # this function, and just call forward.
#    1128 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130     return forward_call(*input, **kwargs)
#    1131 # Do not call functions when jit is used
#    1132 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/anaconda3/envs/ML/lib/python3.9/site-packages/torch/nn/modules/container.py:139, in Sequential.forward(self, input)
#     137 def forward(self, input):
#     138     for module in self:
# --> 139         input = module(input)
#     140     return input
#
# File ~/anaconda3/envs/ML/lib/python3.9/site-packages/torch/nn/modules/module.py:1130, in Module._call_impl(self, *input, **kwargs)
#    1126 # If we don't have any hooks, we want to skip the rest of the logic in
#    1127 # this function, and just call forward.
#    1128 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130     return forward_call(*input, **kwargs)
#    1131 # Do not call functions when jit is used
#    1132 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/anaconda3/envs/ML/lib/python3.9/site-packages/torch/nn/modules/conv.py:457, in Conv2d.forward(self, input)
#     456 def forward(self, input: Tensor) -> Tensor:
# --> 457     return self._conv_forward(input, self.weight, self.bias)
#
# File ~/anaconda3/envs/ML/lib/python3.9/site-packages/torch/nn/modules/conv.py:453, in Conv2d._conv_forward(self, input, weight, bias)
#     449 if self.padding_mode != 'zeros':
#     450     return F.conv2d(F.pad(input, self._reversed_padding_repeated_twice, mode=self.padding_mode),
#     451                     weight, bias, self.stride,
#     452                     _pair(0), self.dilation, self.groups)
# --> 453 return F.conv2d(input, weight, bias, self.stride,
#     454                 self.padding, self.dilation, self.groups)
#
# RuntimeError: Given groups=1, weight of size [64, 4, 3, 3], expected input[20, 2, 32, 32] to have 4 channels, but got 2 channels instead
